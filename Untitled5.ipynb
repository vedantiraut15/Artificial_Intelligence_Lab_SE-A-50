# %% [markdown]
# <a href="https://colab.research.google.com/github/vedantiraut15/Artificial_Intelligence_Lab_SE-A-50/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3cf73b6-7bc8-4b6f-8647-00eecdf83054" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3cf73b6-7bc8-4b6f-8647-00eecdf83054">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Student_data.csv')

# %%
df.head()
# Out:
#   Student_ID  Gender  Age        Major  Attendance_Pct  Study_Hours_Per_Day  \
# 0    ID00001    Male   20  Engineering            83.9                  4.4
# 1    ID00002  Female   24     Business            80.7                  4.0
# 2    ID00003  Female   20  Mathematics            91.5                  3.9
# 3    ID00004  Female   23  Engineering            73.9                  8.8
# 4    ID00005    Male   21    Economics            79.8                  2.2
#
#    Previous_GPA  Sleep_Hours  Social_Hours_Week  Final_CGPA
# 0          2.65          9.1                  8        2.78
# 1          3.58          4.0                  4        3.76
# 2          3.29          6.7                  4        3.75
# 3          3.48          4.0                  6        3.69
# 4          2.66          8.7                  6        2.34

# %%
df.tail()
# Out:
#      Student_ID  Gender  Age             Major  Attendance_Pct  \
# 4995    ID04996  Female   23       Mathematics            83.9
# 4996    ID04997    Male   20         Economics            82.8
# 4997    ID04998    Male   19       Engineering            92.2
# 4998    ID04999  Female   22  Computer Science           100.0
# 4999    ID05000  Female   20       Mathematics            86.5
#
#       Study_Hours_Per_Day  Previous_GPA  Sleep_Hours  Social_Hours_Week  \
# 4995                  2.4          3.21          7.5                  8
# 4996                  7.2          3.12          7.6                  7
# 4997                 13.5          3.55          6.3                  6
# 4998                  2.4          2.86          7.0                  6
# 4999                  7.4          2.49          7.8                  4
#
#       Final_CGPA
# 4995        3.31
# 4996        3.70
# 4997        4.00
# 4998        2.93
# 4999        3.07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_ID           5000 non-null   object
#  1   Gender               5000 non-null   object
#  2   Age                  5000 non-null   int64
#  3   Major                5000 non-null   object
#  4   Attendance_Pct       5000 non-null   float64
#  5   Study_Hours_Per_Day  5000 non-null   float64
#  6   Previous_GPA         5000 non-null   float64
#  7   Sleep_Hours          5000 non-null   float64
#  8   Social_Hours_Week    5000 non-null   int64
#  9   Final_CGPA           5000 non-null   float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 390.8+ KB

# %%
df.describe()
# Out:
#                Age  Attendance_Pct  Study_Hours_Per_Day  Previous_GPA  \
# count  5000.000000     5000.000000          5000.000000   5000.000000
# mean     20.948600       83.795740             4.517840      3.093824
# std       2.017417       12.867904             2.568104      0.476754
# min      18.000000       26.200000             0.100000      1.350000
# 25%      19.000000       75.100000             2.600000      2.760000
# 50%      21.000000       85.050000             4.000000      3.100000
# 75%      23.000000       94.800000             6.000000      3.430000
# max      24.000000      100.000000            14.000000      4.000000
#
#        Sleep_Hours  Social_Hours_Week   Final_CGPA
# count  5000.000000        5000.000000  5000.000000
# mean      7.012060           8.006400     3.272224
# std       1.424377           2.797771     0.507954
# min       4.000000           0.000000     1.160000
# 25%       6.000000           6.000000     2.920000
# ...

# %%
df['Age'].describe()
# Out:
# count    5000.000000
# mean       20.948600
# std         2.017417
# min        18.000000
# 25%        19.000000
# 50%        21.000000
# 75%        23.000000
# max        24.000000
# Name: Age, dtype: float64

# %%
df['Attendance_Pct'].describe()
# Out:
# count    5000.000000
# mean       83.795740
# std        12.867904
# min        26.200000
# 25%        75.100000
# 50%        85.050000
# 75%        94.800000
# max       100.000000
# Name: Attendance_Pct, dtype: float64
